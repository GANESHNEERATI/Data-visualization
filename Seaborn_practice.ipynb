# %% [markdown]
# Seaborn Practice

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# Distribution ploats
# 1.displot
# 2.joinplot
# 3.pairplot

# %% [raw]
# # correclation for relationships between all the features and dependent variable

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# we can view in this heatmap

# %%
sns.heatmap(df.corr())

# %% [markdown]
# bivariate Analysis using joinplot

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %% [markdown]
# pairplot

# %%
sns.pairplot(df,kind='reg')

# %%
sns.pairplot(df,hue='sex')

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.pairplot(df,hue='smoker')

# %%
sns.pairplot(df,hue='day')

# %%
sns.pairplot(df,hue='time')

# %%
#displot used create histograms

# %%
sns.distplot(df['tip'])

# %%
#making kde false

# %%
sns.distplot(df['tip'],kde=False,bins=10)

# %%
#for categorical data we use following plots

# %%
#1.boxplot
#2.violinplot
#3.countplot
#4.barplot

# %%
cnt1=0
cnt2=0
for x in df['sex']:
    if(x=='Male'):
        cnt1=cnt1+1
    else:
        cnt2=cnt2+1

# %%
cnt2
# Out:
# 87

# %%
##countplot shows the count of categorical data
sns.countplot('sex',data=df)

# %%
sns.countplot('smoker',data=df)

# %%
sns.countplot(y='day',data=df)

# %%
#barplots

sns.barplot(x='total_bill',y='sex',data=df)

# %%
sns.barplot(x='smoker',y='total_bill',data=df)

# %%
#Boxplot

# %%
sns.boxplot('sex','total_bill',data=df)

# %%
sns.boxplot(x='day',y='total_bill',data=df,palette='rainbow')

# %%
sns.boxplot(data=df,orient='v')

# %%
#categorize my data basred on other category
sns.boxplot(x='total_bill',y='day',hue='smoker',data=df)

# %%
sns.boxplot(x='total_bill',y='day',hue='time',data=df)

# %%
#violinplot helps us to find  see both kernal destribution estimation with  boxplot

# %%
sns.violinplot(x='total_bill',y='day',data=df,palette='rainbow')
